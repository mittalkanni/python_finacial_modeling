# %%
import pandas as pd
import matplotlib.pyplot as ptl
import seaborn as sns
import numpy as np

data = pd.read_csv("./IPL IMB381IPL2013.csv")



data.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
features = [ 'AGE', 'COUNTRY', 'PLAYING ROLE',
       'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
       'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
       'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE']
features
# Out:
# ['AGE',
#  'COUNTRY',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE']

# %%
data['PLAYING ROLE'].value_counts()
# Out:
# PLAYING ROLE
# Bowler        44
# Batsman       39
# Allrounder    35
# W. Keeper     12
# Name: count, dtype: int64

# %%
pd.crosstab(data["PLAYING ROLE"],data["AGE"])
# Out:
# AGE           1   2   3
# PLAYING ROLE
# Allrounder    4  25   6
# Batsman       5  21  13
# Bowler        7  29   8
# W. Keeper     0  11   1

# %%
data.iloc[0:5,0:10]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B
# 0           0      0.00
# 1         657     71.41
# 2        1269     80.62
# 3         241     84.56
# 4          79     45.93

# %%
data.head(5)
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
data[features]
# Out:
#      AGE COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  \
# 0      2      SA   Allrounder       0       0           0      0.00         0
# 1      2     BAN       Bowler     214      18         657     71.41       185
# 2      2     IND       Bowler     571      58        1269     80.62       288
# 3      1     IND       Bowler     284      31         241     84.56        51
# 4      2     IND      Batsman      63       0          79     45.93         0
# ..   ...     ...          ...     ...     ...         ...       ...       ...
# 125    2     IND      Batsman       0       0           0      0.00         0
# 126    2     PAK      Batsman    6398       7        6814     75.78         3
# 127    2     IND      Batsman    1775       9        8051     87.58       109
# 128    2     IND       Bowler    1114     288         790     73.55       278
# 129    2      SL       Bowler     288      64         343     95.81       108
#
# ...

# %%
data[['COUNTRY','SOLD PRICE']].sort_values("SOLD PRICE",ascending=True)[0:10]
# Out:
#     COUNTRY  SOLD PRICE
# 73      AUS       20000
# 46      IND       24000
# 0        SA       50000
# 1       BAN       50000
# 118      SA       50000
# 5       AUS       50000
# 85      AUS       50000
# 34      AUS       50000
# 61      AUS       80000
# 78      IND       95000

# %%
data[['COUNTRY','SOLD PRICE']].groupby('COUNTRY').mean("SOLD PRICE")
# Out:
#            SOLD PRICE
# COUNTRY
# AUS      4.340909e+05
# BAN      5.000000e+04
# ENG      1.066667e+06
# IND      6.523396e+05
# NZ       5.264286e+05
# PAK      3.305556e+05
# SA       4.275000e+05
# SL       4.237500e+05
# WI       2.791667e+05
# ZIM      1.250000e+05

# %%
pd.get_dummies(data['PLAYING ROLE'])[0:5]
# Out:
#    Allrounder  Batsman  Bowler  W. Keeper
# 0        True    False   False      False
# 1       False    False    True      False
# 2       False    False    True      False
# 3       False    False    True      False
# 4       False     True   False      False

# %%
categorical_feature = ["AGE","COUNTRY","PLAYING ROLE","CAPTAINCY EXP"]
dataEncoded = pd.get_dummies(data[features], columns=categorical_feature,drop_first=True)

dataEncoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   T-RUNS                  130 non-null    int64
#  1   T-WKTS                  130 non-null    int64
#  2   ODI-RUNS-S              130 non-null    int64
#  3   ODI-SR-B                130 non-null    float64
#  4   ODI-WKTS                130 non-null    int64
#  5   ODI-SR-BL               130 non-null    float64
#  6   RUNS-S                  130 non-null    int64
#  7   HS                      130 non-null    int64
#  8   AVE                     130 non-null    float64
#  9   SR-B                    130 non-null    float64
#  10  SIXERS                  130 non-null    int64
#  11  RUNS-C                  130 non-null    int64
#  12  WKTS                    130 non-null    int64
#  13  AVE-BL                  130 non-null    float64
# ...

# %%
X_features = dataEncoded.columns

# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
X = sm.add_constant(dataEncoded)
Y = data[['SOLD PRICE']]

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split( X , Y, train_size = 0.2, random_state = 42 )

# %%
train_X.head()
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 109 to 102
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   const                   26 non-null     float64
#  1   T-RUNS                  26 non-null     int64
#  2   T-WKTS                  26 non-null     int64
#  3   ODI-RUNS-S              26 non-null     int64
#  4   ODI-SR-B                26 non-null     float64
#  5   ODI-WKTS                26 non-null     int64
#  6   ODI-SR-BL               26 non-null     float64
#  7   RUNS-S                  26 non-null     int64
#  8   HS                      26 non-null     int64
#  9   AVE                     26 non-null     float64
#  10  SR-B                    26 non-null     float64
#  11  SIXERS                  26 non-null     int64
#  12  RUNS-C                  26 non-null     int64
#  13  WKTS                    26 non-null     int64
# ...

# %%
train_X.count()
train_y.count()
# Out:
# SOLD PRICE    26
# dtype: int64

# %%
ipl_model_1 = sm.OLS(train_y, train_X).fit()

# ipl_model_1.summary2()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 ipl_model_1 = sm.OLS(train_y, train_X).fit()
#       3 # ipl_model_1.summary2()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:924, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     921     msg = ("Weights are not supported in OLS and will be ignored"
#     922            "An exception will be raised in the next version.")
#     923     warnings.warn(msg, ValueWarning)
# --> 924 super().__init__(endog, exog, missing=missing,
#     925                           hasconst=hasconst, **kwargs)
#     926 if "weights" in self._init_keys:
#     927     self._init_keys.remove("weights")
#
# ...

# %%
train_X
# Out:
#      const  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  RUNS-S  \
# 109    1.0    1546       1        3393     67.58         2       42.0      31
# 37     1.0       0       0        1488     91.40        18       36.2     971
# 29     1.0       0       0           0      0.00         2       39.0      54
# 107    1.0    1586      20        4483     79.41       137       44.6     131
# 116    1.0       0       0         786     91.92         0        0.0    1538
# 1      1.0     214      18         657     71.41       185       37.6       0
# 52     1.0    2506     619         938     61.06       337       43.0      35
# 21     1.0     249      97         239     60.96       187       34.7       4
# 2      1.0     571      58        1269     80.62       288       32.9     167
# 23     1.0    3845     226        3394     88.82       169       33.2      62
# 103    1.0    8042       8        6598     81.58        18       57.0     739
# ...
